# %% [markdown]
# # Homework 1 - Sean Saito
#
# Implementation of 2D image convolution. Uses the following kernels:
# * Sobel kernel
# * Gaussian kernel
# * Haar-like masks

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
from PIL import Image

# Global variables
im_file = "image.png"
grey_file = "greyscale.png"

# Greyscale the image
img = Image.open(im_file).convert('L')
img.save(grey_file)

# %%
# Now get the image via matplotlib
img = mpimg.imread(grey_file)

# Show original
plt.imshow(img, cmap='Greys_r')

# %%
# The numpy array
img
# Out:
# array([[ 0.49803922,  0.49803922,  0.49411765, ...,  0.19215687,
#          0.23921569,  0.25490198],
#        [ 0.49803922,  0.49803922,  0.49411765, ...,  0.23921569,
#          0.27058825,  0.26666668],
#        [ 0.49803922,  0.49803922,  0.49411765, ...,  0.29019609,
#          0.3019608 ,  0.27843139],
#        ...,
#        [ 0.6156863 ,  0.61960787,  0.61960787, ...,  0.23137255,
#          0.23921569,  0.24313726],
#        [ 0.60000002,  0.59607846,  0.59215689, ...,  0.21176471,
#          0.22352941,  0.22745098],
#        [ 0.55686277,  0.54901963,  0.53725493, ...,  0.16078432,
#          0.16470589,  0.16470589]], dtype=float32)

# %%
# Kernels

gaussian_kernel = np.array([
        [1, 4, 7, 4, 1],
        [4, 16, 26, 16, 4],
        [7, 26, 41, 26, 7],
        [4, 16, 26, 16, 4],
        [1, 4, 7, 4, 1]
    ]) / 273.0

sobel_x = np.array([
        [-1, 0, 1],
        [-2, 0, 2],
        [-1, 0, 1]
    ])

sobel_y = np.array([
        [1, 2, 1],
        [0, 0, 0],
        [-1, -2, -1]
    ])

haar_white = np.zeros((10, 10))
haar_white.fill(1)
haar_black = np.zeros((10, 10))
haar_black.fill(-1)

haar_edge_x = np.hstack((np.vstack((haar_white, haar_black)) 
                         for _ in range(2)))
haar_edge_y = np.vstack((np.hstack((haar_white, haar_black))
                         for _ in range(2)))

haar_line_x = np.hstack((np.vstack((haar_white, haar_black, haar_white))
                         for _ in range(3)))
                        
haar_line_y = np.vstack((np.hstack((haar_white, haar_black, haar_white))
                         for _ in range(3)))

haar_checkers = np.vstack((np.hstack((haar_white, haar_black)), 
                          np.hstack((haar_black, haar_white))))

# %%
# Dictionary of kernels used for convolution

kernels = {
    "gaussian": [gaussian_kernel],
    "sobel": [sobel_x, sobel_y],
    "haar_edge": [haar_edge_x, haar_edge_y],
    "haar_line": [haar_line_x, haar_line_y],
    "haar_checkers": [haar_checkers]
}

# %%
def convolution(X, kernel):
    """
    Apply convolution over an image using a kernel
    
    Args:
        X         : numpy.ndarray
            input image
        kernel    : list
            list of filters. All filters should have the same dimension
    """
    
    shape = X.shape
    kernel_shape = kernel[0].shape
    
    # Number of rows and columns
    target_x = shape[0] - kernel_shape[0] + 1
    target_y = shape[1] - kernel_shape[1] + 1
    
    target = np.zeros((target_x, target_y))
    
    for i in range(target_x):
        for j in range(target_y):
            input_sub = X[i:(i+kernel_shape[0]), j:(j+kernel_shape[1])]
            combined = 0
            for f in kernel:
                interm = np.sum(np.multiply(input_sub, f))
                combined += np.absolute(interm)
            target[i, j] = combined
    
    return target

# %%
# Gaussian convolution
gauss_res = convolution(img, kernels["gaussian"])
plt.imshow(gauss_res, cmap="Greys_r")

# %%
# What does it look like?
gauss_res[:10,]
# Out:
# array([[ 0.49506572,  0.49316958,  0.49114415, ...,  0.18332257,
#          0.22202112,  0.25898155],
#        [ 0.49506572,  0.49316958,  0.49114415, ...,  0.22183438,
#          0.25172737,  0.27710983],
#        [ 0.49506572,  0.49316958,  0.49114415, ...,  0.25725779,
#          0.27001366,  0.28085902],
#        ...,
#        [ 0.49785247,  0.49773756,  0.49760827, ...,  0.29219279,
#          0.29536739,  0.29562595],
#        [ 0.49803922,  0.49803922,  0.49803922, ...,  0.28924802,
#          0.28907564,  0.28373197],
#        [ 0.49803922,  0.49803922,  0.49803922, ...,  0.28220931,
#          0.27178052,  0.25855061]])

# %%
# Sobel convolution
sobel_res = convolution(img, kernels["sobel"])
plt.imshow(sobel_res, cmap="Greys_r")

# %%
# What does it look like?
sobel_res[:10,]
# Out:
# array([[ 0.01568627,  0.01568627,  0.01568627, ...,  0.74509804,
#          0.71372554,  0.35294124],
#        [ 0.01568627,  0.01568627,  0.01568627, ...,  0.76862749,
#          0.53333339,  0.16470587],
#        [ 0.01568627,  0.01568627,  0.01568627, ...,  0.50980398,
#          0.20392159,  0.07843137],
#        ...,
#        [ 0.00784314,  0.01568627,  0.02352941, ...,  0.09411764,
#          0.09411764,  0.0862745 ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.03921568,
#          0.01568627,  0.14117646],
#        [ 0.        ,  0.        ,  0.        , ...,  0.10980392,
#          0.24313727,  0.37647063]])

# %%
# Haar-Edge convolution
haar_edge_res = convolution(img, kernels["haar_edge"])
plt.imshow(haar_edge_res, cmap="Greys_r")

# %%
# What does it look like?
haar_edge_res[:10,]
# Out:
# array([[  0.69019604,   0.64313722,   0.5960784 , ...,  15.11372603,
#          15.37254943,  14.77647087],
#        [  0.70588231,   0.66666663,   0.62745094, ...,  13.73333366,
#          13.74117668,  13.0588236 ],
#        [  0.72156858,   0.69019604,   0.65882349, ...,  12.22745109,
#          12.21176472,  11.63921559],
#        ...,
#        [  1.01960957,   1.01960957,   1.01960957, ...,  19.97647174,
#          19.64705987,  18.21960878],
#        [  1.09804153,   1.09804153,   1.09804153, ...,  19.95294215,
#          19.22353028,  17.52156937],
#        [  1.25490487,   1.25490487,   1.25490487, ...,  18.65098117,
#          17.63137321,  15.71764761]])

# %%
# Haar-Line convolution
haar_line_res = convolution(img, kernels["haar_line"])
plt.imshow(haar_line_res, cmap="Greys_r")

# %%
# What does it look like?
haar_line_res[:10,]
# Out:
# array([[ 299.01177073,  298.93333936,  298.85490799, ...,  146.72941591,
#          147.89020009,  149.3254942 ],
#        [ 299.41961503,  299.34118366,  299.26275229, ...,  153.01961227,
#          155.25490631,  157.44314159],
#        [ 299.82745934,  299.74902797,  299.6705966 , ...,  159.72549479,
#          162.88627903,  165.49020062],
#        ...,
#        [ 302.30589235,  302.38432395,  302.40001041, ...,  189.28628013,
#          194.40784901,  196.7215746 ],
#        [ 302.05491114,  302.50981337,  302.80000967, ...,  190.07843682,
#          195.22353512,  197.67843723],
#        [ 300.75294954,  301.70981258,  302.44706774, ...,  187.49020123,
#          192.57255444,  195.20784873]])

# %%
# Haar-Checkers convolution
haar_checkers_res = convolution(img, kernels["haar_checkers"])
plt.imshow(haar_checkers_res, cmap="Greys_r")

# %%
# What does it look like?
haar_checkers_res[:10,]
# Out:
# array([[ 0.25098038,  0.26666665,  0.28235292, ...,  0.81568626,
#          2.28235313,  5.36078471],
#        [ 0.17254901,  0.19215685,  0.21176469, ...,  1.96470603,
#          4.54117677,  6.94902009],
#        [ 0.09411764,  0.11764705,  0.14117646, ...,  4.05882379,
#          5.921569  ,  7.50980444],
#        ...,
#        [ 0.18823504,  0.14117616,  0.09411728, ...,  4.37647108,
#          1.88627485,  1.43529391],
#        [ 0.18823504,  0.14117616,  0.09411728, ...,  2.85098088,
#          0.34509772,  4.47843125],
#        [ 0.14117622,  0.09411734,  0.04705846, ...,  0.47451017,
#          3.14117631,  7.73333337]])
